# %%
# Dependencies
import numpy as np
import pandas as pd
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# Import datetime
import datetime as dt

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract
# Code taken from: https://stackoverflow.com/questions/11616260/how-to-get-all-objects-with-a-date-that-fall-in-a-specific-month-sqlalchemy/31641488
# 
# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 

temperature_june = session.query(Measurement.tobs).filter(extract('month', Measurement.date)==6).all()
temperature_june
# Out:
# [(78.0),
#  (76.0),
#  (78.0),
#  (76.0),
#  (77.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (79.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (77.0),
#  (82.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (76.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (73.0),
#  (70.0),
#  (76.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (78.0),
#  (77.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (75.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (78.0),
#  (76.0),
#  (77.0),
#  (75.0),
#  (77.0),
#  (76.0),
#  (76.0),
#  (75.0),
#  (77.0),
#  (77.0),
#  (76.0),
#  (78.0),
#  (77.0),
#  (76.0),
#  (77.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (77.0),
#  (78.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (76.0),
#  (75.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (76.0),
#  (73.0),
#  (73.0),
#  (75.0),
#  (77.0),
#  (76.0),
#  (77.0),
#  (79.0),
#  (78.0),
#  (79.0),
#  (78.0),
# ...

# %%
#  3. Convert the June temperatures to a list.
temperature_june = list(temperature_june)
temperature_june
# Out:
# [(78.0),
#  (76.0),
#  (78.0),
#  (76.0),
#  (77.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (79.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (77.0),
#  (82.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (76.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (73.0),
#  (70.0),
#  (76.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (78.0),
#  (77.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (77.0),
#  (78.0),
#  (78.0),
#  (75.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (78.0),
#  (76.0),
#  (77.0),
#  (75.0),
#  (77.0),
#  (76.0),
#  (76.0),
#  (75.0),
#  (77.0),
#  (77.0),
#  (76.0),
#  (78.0),
#  (77.0),
#  (76.0),
#  (77.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (77.0),
#  (78.0),
#  (77.0),
#  (77.0),
#  (77.0),
#  (76.0),
#  (75.0),
#  (76.0),
#  (76.0),
#  (77.0),
#  (76.0),
#  (73.0),
#  (73.0),
#  (75.0),
#  (77.0),
#  (76.0),
#  (77.0),
#  (79.0),
#  (78.0),
#  (79.0),
#  (78.0),
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
temperature_june_df = pd.DataFrame(temperature_june)
temperature_june_df
# Out:
#       tobs
# 0     78.0
# 1     76.0
# 2     78.0
# 3     76.0
# 4     77.0
# ...    ...
# 1695  79.0
# 1696  74.0
# 1697  74.0
# 1698  76.0
# 1699  75.0
#
# [1700 rows x 1 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
temperature_june_df.describe()
# Out:
#               tobs
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
temperature_december = session.query(Measurement.tobs).filter(extract('month', Measurement.date)==12).all()

# %%
# 7. Convert the December temperatures to a list.
temperature_december = list(temperature_december)

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
temperature_december_df = pd.DataFrame(temperature_december)

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
temperature_december_df.describe()
# Out:
#               tobs
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %%
# Return the proportion of days in our dataset which had no precipitation
zero_precipitation_proportion = (session.query(Measurement.prcp).filter(Measurement.prcp == '0').count()/session.query(Measurement.prcp).count())
zero_precipitation_proportion
# Out:
# 0.4186700767263427

# %%
session.query(Measurement.prcp).count()
# Out:
# 19550

# %%
func.month()
# Out:
# <sqlalchemy.sql.functions.Function at 0x2190ac7a788; month>

# %%
# Create a dataframe with the average temperatures from each month

avg_temps = session.query(extract('month',Measurement.date),
            func.avg(Measurement.tobs)).\
    group_by(extract('month',Measurement.date)).all()

# %%
month_list = [
    'January',
    'February',
    'March',
    'April',
    'May',
    'June',
    'July',
    'August',
    'September',
    'October',
    'November',
    'December'
]

# %%
# Create a dataframe with the average temperatures from each month
# Query the database
avg_temps = session.query(extract('month',Measurement.date),
            func.avg(Measurement.tobs)).\
    group_by(extract('month',Measurement.date)).all()
# Create and format the dataframe 
avg_temps_df = pd.DataFrame(avg_temps,columns=["Month","avg_temp (F)"])
avg_temps_df.set_index(avg_temps_df['Month'], inplace=True)
avg_temps_df.index = month_list
avg_temps_df.drop(["Month"],axis=1)
# Out:
#            avg_temp (F)
# January       68.726115
# February      69.442236
# March         70.059067
# April         72.357268
# May           73.680900
# June          74.944118
# July          76.082408
# August        76.412454
# September     76.164865
# October       75.391388
# November      73.252688
# December      71.041529
